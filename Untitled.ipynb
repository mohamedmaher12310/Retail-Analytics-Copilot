# %%
# !python run_agent_hybrid.py --batch sample_questions_hybrid_eval.jsonl --out outputs_hybrid.jsonl
# Out:
# --- Starting Hybrid Agent Evaluation (with Output Contract Validation) ---
# Loaded 10 questions from sample_questions_hybrid_eval.jsonl
#
# [1/10] Processing: rag_policy_beverages_return_days
#   Question: According to the product policy, what is the return window (days) for ...
#   Running workflow...
#   Normalized. Answer: None
#
# [2/10] Processing: hybrid_top_category_qty_summer_1997
#   Question: During 'Summer Beverages 1997' as defined in the marketing calendar, w...
#   Running workflow...
#   Normalized. Answer: None
#
# [3/10] Processing: hybrid_aov_winter_1997
#   Question: Using the AOV definition from the KPI docs, what was the Average Order...
#   Running workflow...
#   Normalized. Answer: None
#
# [4/10] Processing: sql_top3_products_by_revenue_alltime
#   Question: Top 3 products by total revenue all-time. Revenue uses Order Details: ...
#   Running workflow...
#   Normalized. Answer: None
#
# [5/10] Processing: hybrid_revenue_beverages_summer_1997
#   Question: Total revenue from the 'Beverages' category during 'Summer Beverages 1...
#   Running workflow...
#   Normalized. Answer: None
#
# [6/10] Processing: hybrid_best_customer_margin_1997
#   Question: Per the KPI definition of gross margin, who was the top customer by gr...
#   Running workflow...
#   Normalized. Answer: None
#
# [7/10] Processing: hybrid_top_product_category_summer_1997
#   Question: During 'Summer Beverages 1997', which product category had the highest...
#   Running workflow...
#   Normalized. Answer: None
#
# [8/10] Processing: sql_top3_customers_by_revenue_alltime
#   Question: Top 3 customers by total revenue all-time. Revenue uses Order Details:...
#   Running workflow...
#   Normalized. Answer: None
#
# [9/10] Processing: rag_policy_beverages_return_days
#   Question: According to the product policy, what is the return window (days) for ...
#   Running workflow...
#   Normalized. Answer: None
#
# [10/10] Processing: hybrid_aov_summer_1997
#   Question: Using the AOV definition from the KPI docs, what was the Average Order...
#   Running workflow...
#   Normalized. Answer: None
#
# --- Writing Results (Output Contract Format) ---
# Wrote 10 results to outputs_hybrid.jsonl
#
# --- Summary ---
# Valid: 0/10 | Partial: 0 | Error: 10
# Output file: outputs_hybrid.jsonl
# C:\Users\Mohamed Maher\anaconda3\envs\langchain_env\lib\site-packages\pydantic\_internal\_fields.py:184: UserWarning: Field name "schema" shadows an attribute in parent "Signature";
#   warnings.warn(

# %%
# !python run_agent_hybrid.py --batch sample_questions_hybrid_eval.jsonl --out outputs_hybrid.jsonl
# Out:
# --- Starting Hybrid Agent Evaluation (with Output Contract Validation & Repair) ---
# Loaded 10 questions from sample_questions_hybrid_eval.jsonl
#
# [1/10] Processing: rag_policy_beverages_return_days
#   Format: int | Question: According to the product policy, what is the return window (...
#   [Attempt 1] SQL error, retrying (repair 1/2)...
#   [Attempt 2] SQL error, retrying (repair 2/2)...
#   [Attempt 3] FAILED. No valid answer after 2 repairs.
# Confidence: 0.0 | Citations: ['Discounts', 'Inventory', 'OrderDetails', 'ProductPolicy', 'Products', 'Returns']
#
# [2/10] Processing: hybrid_top_category_qty_summer_1997
#   Format: {category:str, quantity:int} | Question: During 'Summer Beverages 1997' as defined in the marketing c...
#   [Attempt 1] SQL error, retrying (repair 1/2)...
#   [Attempt 2] SQL error, retrying (repair 2/2)...
#   [Attempt 3] FAILED. No valid answer after 2 repairs.
# Confidence: 0.0 | Citations: ["DB tables (e.g., 'Sales') and doc IDs (e.g., 'marketing::chunk1')", 'OrderDetails', 'Sales']
#
# [3/10] Processing: hybrid_aov_winter_1997
#   Format: float | Question: Using the AOV definition from the KPI docs, what was the Ave...
#   [Attempt 1] SQL error, retrying (repair 1/2)...
#   [Attempt 2] SQL error, retrying (repair 2/2)...
#   [Attempt 3] FAILED. No valid answer after 2 repairs.
# Confidence: 0.0 | Citations: ['OrderDetails']
#
# [4/10] Processing: sql_top3_products_by_revenue_alltime
#   Format: list[{product:str, revenue:float}] | Question: Top 3 products by total revenue all-time. Revenue uses Order...
#   [Attempt 1] SQL error, retrying (repair 1/2)...
#   [Attempt 2] SQL error, retrying (repair 2/2)...
#   [Attempt 3] FAILED. No valid answer after 2 repairs.
# Confidence: 0.0 | Citations: ['Order']
#
# [5/10] Processing: hybrid_revenue_beverages_summer_1997
#   Format: float | Question: Total revenue from the 'Beverages' category during 'Summer B...
#   [Attempt 1] SQL error, retrying (repair 1/2)...
#   [Attempt 2] SQL error, retrying (repair 2/2)...
#   [Attempt 3] FAILED. No valid answer after 2 repairs.
# Confidence: 0.0 | Citations: ["DB tables (e.g., 'Orders') and doc IDs (e.g., 'marketing::chunk1') are not provided in this context.", 'OrderDetails']
#
# [6/10] Processing: hybrid_best_customer_margin_1997
#   Format: {customer:str, margin: float} | Question: Per the KPI definition of gross margin, who was the top cust...
#   [Attempt 1] SQL error, retrying (repair 1/2)...
#   [Attempt 2] SQL error, retrying (repair 2/2)...
#   [Attempt 3] FAILED. No valid answer after 2 repairs.
# Confidence: 0.0 | Citations: ["DB tables (e.g., 'Orders') and doc IDs (e.g., 'marketing::chunk1')", 'OrderDetails', 'Orders']
#
# [7/10] Processing: hybrid_top_product_category_summer_1997
#   Format: {category:str, quantity:int} | Question: During 'Summer Beverages 1997', which product category had t...
#   [Attempt 1] SQL error, retrying (repair 1/2)...
#   [Attempt 2] SQL error, retrying (repair 2/2)...
#   [Attempt 3] FAILED. No valid answer after 2 repairs.
# Confidence: 0.0 | Citations: ['OrderDetails']
#
# [8/10] Processing: sql_top3_customers_by_revenue_alltime
#   Format: list[{customer:str, revenue:float}] | Question: Top 3 customers by total revenue all-time. Revenue uses Orde...
#   [Attempt 1] SQL error, retrying (repair 1/2)...
#   [Attempt 2] SQL error, retrying (repair 2/2)...
#   [Attempt 3] FAILED. No valid answer after 2 repairs.
# Confidence: 0.0 | Citations: ['OrderDetails']
#
# [9/10] Processing: rag_policy_beverages_return_days
#   Format: int | Question: According to the product policy, what is the return window (...
#   [Attempt 1] SQL error, retrying (repair 1/2)...
#   [Attempt 2] SQL error, retrying (repair 2/2)...
#   [Attempt 3] FAILED. No valid answer after 2 repairs.
# Confidence: 0.0 | Citations: ['Discounts', 'Inventory', 'OrderDetails', 'ProductPolicy', 'Products', 'Returns']
#
# [10/10] Processing: hybrid_aov_summer_1997
#   Format: float | Question: Using the AOV definition from the KPI docs, what was the Ave...
#   [Attempt 1] SQL error, retrying (repair 1/2)...
#   [Attempt 2] SQL error, retrying (repair 2/2)...
#   [Attempt 3] FAILED. No valid answer after 2 repairs.
# Confidence: 0.0 | Citations: ['OrderDetails']
#
# --- Writing Results (Output Contract Format) ---
# Wrote 10 results to outputs_hybrid.jsonl
#
# --- Summary ---
# Valid: 0/10 | Partial: 0 | Error: 10
# Output file: outputs_hybrid.jsonl
# C:\Users\Mohamed Maher\anaconda3\envs\langchain_env\lib\site-packages\pydantic\_internal\_fields.py:184: UserWarning: Field name "schema" shadows an attribute in parent "Signature";
#   warnings.warn(

# %%
# !python run_agent_hybrid.py --batch sample_questions_hybrid_eval.jsonl --out outputs_hybrid.jsonl
