# %%
# !python run_agent_hybrid.py --batch sample_questions_hybrid_eval.jsonl --out outputs_hybrid.jsonl
# Out:
# C:\Users\Mohamed Maher\anaconda3\envs\langchain_env\lib\site-packages\pydantic\_internal\_fields.py:184: UserWarning: Field name "schema" shadows an attribute in parent "Signature";
#   warnings.warn(
# Traceback (most recent call last):
#   File "C:\Users\Mohamed Maher\Desktop\trial3\your_project\run_agent_hybrid.py", line 14, in <module>
#     from agent.graph_hybrid import app
#   File "C:\Users\Mohamed Maher\Desktop\trial3\your_project\agent\graph_hybrid.py", line 5, in <module>
#     from rag.retrieval import LocalRetriever
# ModuleNotFoundError: No module named 'rag'
